# %%
# %matplotlib widget
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('ars.stats.df',delimiter=' ')
configs = []
for run in df1['run']:
    if run < 5:
        config = 'shasta'
    elif run < 10:
        config = 'hifiasm'
    elif run < 20:
        config = 'hs_shuf'
    elif run < 40:
        config = 'either'
    elif run < 102:
        config = 'LOW_shasta'
    elif run < 104:
        config = 'LOW_hifiasm'
    elif run < 107:
        config = 'LOW_hs_shuf'
    elif run < 110:
        config = 'LOW_either'
    elif run < 203:
        config = 'peregrine'
    elif run < 206:
        config = 'raven'
    elif run < 209:
        config = 'flye'
    elif run < 210:
        config = 'hicanu'
    elif run < 220:
        config = 'all_shuf'
    elif run < 240:
        config = 'all_eith'
    configs.append(config)
df1['config'] = configs
df1['ref']='ARS'

df2 = pd.read_csv('angus.stats.df',delimiter=' ')
df3 = pd.read_csv('simmental.stats.df',delimiter=' ')
configs = []
for run in df2['run']:
    if run < 2:
        config = 'shasta'
    elif run < 4:
        config = 'hifiasm'
    elif run < 7:
        config = 'hs_shuf'
    elif run < 10:
        config = 'either'
    configs.append(config)
df2['config']=configs
df3['config']=configs
df2['ref']='Angus'
df3['ref']='Simmental'

df = pd.concat([df1,df2,df3])

# %%
sns.pairplot(data=df,corner=True,hue='run',diag_kind='hist')

# %%
df[(df['ref']!='XARS')&(df['non_ref_node_len']<1e17)&(df['chrom']==28)].groupby(['config','ref']).mean()
# Out:
#                          run  chrom   total_node      len_node     ref_node  \
# config      ref
# LOW_either  ARS        108.0   28.0  5862.000000  4.697107e+07  3891.333333
# LOW_hifiasm ARS        102.5   28.0  5696.000000  4.684450e+07  3846.000000
# LOW_hs_shuf ARS        105.0   28.0  6088.000000  4.699464e+07  4000.666667
# LOW_shasta  ARS        100.5   28.0  5844.000000  4.692189e+07  3904.500000
# all_eith    ARS        229.5   28.0  5841.650000  4.700082e+07  3894.700000
# all_shuf    ARS        214.5   28.0  7046.300000  4.746611e+07  4312.300000
# either      ARS         29.5   28.0  5801.500000  4.698696e+07  3864.350000
#             Angus        8.0   28.0  4182.000000  3.735875e+07  2820.666667
#             Simmental    8.0   28.0  5713.333333  4.661946e+07  3860.333333
# flye        ARS        207.0   28.0  5743.666667  4.685606e+07  3871.666667
# hicanu      ARS        209.0   28.0  5680.000000  4.683644e+07  3822.000000
# hifiasm     ARS          7.0   28.0  5692.600000  4.685288e+07  3839.800000
#             Angus        2.5   28.0  4126.500000  3.745268e+07  2792.500000
#             Simmental    2.5   28.0  5621.500000  4.664371e+07  3811.000000
# hs_shuf     ARS         14.5   28.0  6024.200000  4.707444e+07  3955.800000
#             Angus        5.0   28.0  4357.000000  3.742539e+07  2912.333333
#             Simmental    5.0   28.0  5900.666667  4.668938e+07  3970.666667
# peregrine   ARS        201.0   28.0  5622.000000  4.685104e+07  3794.666667
# peregrine   ARS        7941.333333  4320.000000  3521.000000  100.333333
# raven       ARS        8719.333333  4490.666667  3740.000000  488.666667
# shasta      ARS        8210.000000  4391.600000  3629.600000  188.800000
#             Angus      5869.000000  3217.000000  2564.000000   88.000000
#             Simmental  8080.000000  4403.500000  3582.500000   94.000000

# %%
df2 = df.melt(id_vars=['run','config','chrom','ref'])

# %%
dg=df[df['non_ref_node_len']<4e6]

# %%
orders = ['hicanu','peregrine','hifiasm','shasta','flye','raven','either','all_eith','LOW_hifiasm','LOW_shasta','LOW_either']
if False:
    orders.extend(['LOW_hs_shuf','hs_shuf','all_shuf'])
orders=['hifiasm','shasta']
sns.catplot(data=df2,x='chrom',y='value',kind='point',hue='config',row='variable',col='ref',sharey='row',ci='sd',estimator=np.median,hue_order=orders)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import scipy.stats as ss
from collections import Counter
dfq=df[df['chrom']==1]

raws = []
count= 0
for t in ['total_node', 'len_node', 'ref_node', 'ref_node_len', 'non_ref_node', 'non_ref_node_len', 'total_edges', 'total_rr', 'total_rn', 'total_nn']:#['non_ref_node_len','total_nn']:
    for j in combinations(['hicanu','peregrine','hifiasm','shasta','flye','raven','either','all_either','LOW_hifiasm','LOW_shasta','LOW_either'],2):
        try:
            val = ss.mannwhitneyu(dfq[dfq['config']==j[0]][t],dfq[dfq['config']==j[1]][t])[1]
        except:
            continue
        count += 1
        if val < 0.05:
            print('*******',j,t,val)
            raws.append(j)
print(Counter(raws))
            #print(dfq[dfq['config']==j[0]][t],dfq[dfq['config']==j[1]][t])
print(count)

# %%
c=Counter(raws)
sum(c.values())
# Out:
# 168

# %%
df[(df['non_ref_node_len']>8e6)&(df['chrom']!=99)]
# Out:
#       run  chrom  total_node   len_node  ref_node  ref_node_len  non_ref_node  \
# 151     5      7       11223  129448882      7305     110682743          3918
# 209     7      7       11258  129458720      7300     110682743          3958
# 243     8     12       11562   96990775      7249      87216183          4313
# 359    12     12       12007   97073519      7467      87216183          4540
# 388    13     12       12035   97067325      7434      87216183          4601
# 417    14     12       12224   97565460      7446      87216183          4778
# 446    15     12       11957   97081823      7487      87216183          4470
# 499    17      7       11822  129734759      7557     110682743          4265
# 504    17     12       12008   95256697      7479      87216183          4529
# 1171  200     12       11855   97638987      7114      87216183          4741
# 1519  212     12       13938   95831260      8073      87216183          5865
# 1577  214     12       14126   98415790      8019      87216183          6107
# 1606  215     12       14425   98519521      8066      87216183          6359
# 1635  216     12       13856   95243834      8091      87216183          5765
# 1722  219     12       14738   98640580      8039      87216183          6699
# 2389  102     12       11472   96788539      7241      87216183          4231
# 8       0      9       11532  116755354      7414     108212080          4118
# 37      1      9       11508  116651080      7411     108212080          4097
# 64      2      7       11077  127708755      7533     110277844          3544
# 66      2      9       11444  117226334      7340     108212080          4104
